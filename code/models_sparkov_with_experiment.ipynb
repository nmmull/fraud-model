# %%
# https://www.kaggle.com/datasets/kartik2112/fraud-detection?select=fraudTrain.csv
# dataset preprocessing
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

df_train = pd.read_csv("fraudTrain.csv")
df_test = pd.read_csv("fraudTest.csv")

# data preprocessing plus exploratory data analysis
def preprocess(df):
    # combine first and last name to one column
    #df['name'] = df['first'] + df['last']
    df = df.drop(columns=['first','last'])

    # combine address into

    # drop time, also drop data for a baseline test (can manipulate what data to add back in later)
    df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'])
    df = df.sort_values(by="trans_date_trans_time", ascending=True)
    df = df.drop(columns=['trans_date_trans_time', 'job', 'dob', 'unix_time', 'city_pop', 'category', 'street', 'city', 'state', 'zip'
                          , 'gender', 'cc_num', 'trans_num'])

    return df

df_train = preprocess(df_train)
df_test = preprocess(df_test)

# training data
X_training = df_train.drop('is_fraud', axis=1)
y_training = df_train['is_fraud']

# testing data
X_test = df_test.drop('is_fraud', axis=1)
y_test = df_test['is_fraud']

# %%
# encoding for categorical data
ct = ColumnTransformer(
    transformers=[
        ('merchants', OneHotEncoder(handle_unknown='ignore'), ['merchant'])
    ],
    remainder='passthrough'
)

ct.fit(X_training)

X_training_ohe = ct.transform(X_training)
X_testing_ohe  = ct.transform(X_test)
print(ct.get_feature_names_out())
# Out:
# ['merchants__merchant_fraud_Abbott-Rogahn'
#  'merchants__merchant_fraud_Abbott-Steuber'
#  'merchants__merchant_fraud_Abernathy and Sons'
#  'merchants__merchant_fraud_Abshire PLC'
#  'merchants__merchant_fraud_Adams, Kovacek and Kuhlman'
#  'merchants__merchant_fraud_Adams-Barrows'
#  'merchants__merchant_fraud_Altenwerth, Cartwright and Koss'
#  'merchants__merchant_fraud_Altenwerth-Kilback'
#  'merchants__merchant_fraud_Ankunding LLC'
#  'merchants__merchant_fraud_Ankunding-Carroll'
#  'merchants__merchant_fraud_Armstrong, Walter and Gottlieb'
#  'merchants__merchant_fraud_Auer LLC'
#  'merchants__merchant_fraud_Auer-Mosciski'
#  'merchants__merchant_fraud_Auer-West'
#  'merchants__merchant_fraud_Bahringer Group'
#  'merchants__merchant_fraud_Bahringer, Bergnaum and Quitzon'
#  'merchants__merchant_fraud_Bahringer, Osinski and Block'
#  'merchants__merchant_fraud_Bahringer, Schoen and Corkery'
#  'merchants__merchant_fraud_Bahringer-Larson'
#  'merchants__merchant_fraud_Bahringer-Streich'
#  'merchants__merchant_fraud_Bailey-Morar'
#  'merchants__merchant_fraud_Balistreri-Nader'
#  'merchants__merchant_fraud_Barrows PLC'
#  'merchants__merchant_fraud_Bartoletti and Sons'
#  'merchants__merchant_fraud_Bartoletti-Wunsch'
#  'merchants__merchant_fraud_Barton Inc'
#  'merchants__merchant_fraud_Barton LLC'
#  'merchants__merchant_fraud_Bashirian Group'
#  'merchants__merchant_fraud_Bauch-Blanda'
#  'merchants__merchant_fraud_Bauch-Raynor'
#  'merchants__merchant_fraud_Baumbach Ltd'
#  'merchants__merchant_fraud_Baumbach, Feeney and Morar'
#  'merchants__merchant_fraud_Baumbach, Hodkiewicz and Walsh'
#  'merchants__merchant_fraud_Baumbach, Strosin and Nicolas'
#  'merchants__merchant_fraud_Bechtelar-Rippin'
#  'merchants__merchant_fraud_Becker, Harris and Harvey'
#  'merchants__merchant_fraud_Bednar Group'
#  'merchants__merchant_fraud_Bednar Inc'
#  'merchants__merchant_fraud_Bednar PLC'
#  'merchants__merchant_fraud_Beer-Jast'
#  'merchants__merchant_fraud_Beier LLC'
#  'merchants__merchant_fraud_Beier and Sons'
#  'merchants__merchant_fraud_Beier-Hyatt'
#  'merchants__merchant_fraud_Berge LLC'
#  'merchants__merchant_fraud_Berge, Kautzer and Harris'
#  'merchants__merchant_fraud_Berge-Hills'
#  'merchants__merchant_fraud_Berge-Ullrich'
#  'merchants__merchant_fraud_Bernhard Inc'
#  'merchants__merchant_fraud_Bernhard, Grant and Langworth'
#  'merchants__merchant_fraud_Bernhard-Lesch'
#  'merchants__merchant_fraud_Bernier and Sons'
#  'merchants__merchant_fraud_Bernier, Streich and Jewess'
#  'merchants__merchant_fraud_Bernier, Volkman and Hoeger'
#  'merchants__merchant_fraud_Bins, Balistreri and Beatty'
#  'merchants__merchant_fraud_Bins-Howell'
#  'merchants__merchant_fraud_Bins-Rice'
#  'merchants__merchant_fraud_Bins-Tillman'
#  'merchants__merchant_fraud_Block Group'
#  'merchants__merchant_fraud_Block-Hauck'
#  'merchants__merchant_fraud_Block-Parisian'
#  'merchants__merchant_fraud_Bode-Rempel'
#  'merchants__merchant_fraud_Bode-Schuster'
#  'merchants__merchant_fraud_Boehm, Block and Jakubowski'
#  'merchants__merchant_fraud_Boehm, Predovic and Reinger'
#  'merchants__merchant_fraud_Bogisich Inc'
#  'merchants__merchant_fraud_Bogisich-Homenick'
#  'merchants__merchant_fraud_Bogisich-Weimann'
#  'merchants__merchant_fraud_Botsford Ltd'
#  'merchants__merchant_fraud_Botsford PLC'
#  'merchants__merchant_fraud_Botsford and Sons'
#  'merchants__merchant_fraud_Boyer PLC'
#  'merchants__merchant_fraud_Boyer-Haley'
#  'merchants__merchant_fraud_Boyer-Reichert'
#  'merchants__merchant_fraud_Bradtke PLC'
#  'merchants__merchant_fraud_Bradtke, Torp and Bahringer'
#  'merchants__merchant_fraud_Breitenberg LLC'
#  'merchants__merchant_fraud_Breitenberg-Hermiston'
#  'merchants__merchant_fraud_Brekke and Sons'
#  'merchants__merchant_fraud_Brown Inc'
#  'merchants__merchant_fraud_Brown PLC'
#  'merchants__merchant_fraud_Brown, Homenick and Lesch'
#  'merchants__merchant_fraud_Brown-Greenholt'
#  'merchants__merchant_fraud_Bruen-Yost'
#  'merchants__merchant_fraud_Buckridge PLC'
#  'merchants__merchant_fraud_Carroll PLC'
#  'merchants__merchant_fraud_Cartwright PLC'
#  'merchants__merchant_fraud_Cartwright-Harris'
#  'merchants__merchant_fraud_Casper, Hand and Zulauf'
#  'merchants__merchant_fraud_Cassin-Harvey'
#  'merchants__merchant_fraud_Champlin and Sons'
#  'merchants__merchant_fraud_Champlin, Rolfson and Connelly'
#  'merchants__merchant_fraud_Champlin-Casper'
#  'merchants__merchant_fraud_Christiansen, Goyette and Schamberger'
#  'merchants__merchant_fraud_Christiansen-Gusikowski'
#  'merchants__merchant_fraud_Cole PLC'
#  'merchants__merchant_fraud_Cole, Hills and Jewess'
#  'merchants__merchant_fraud_Collier Inc'
#  'merchants__merchant_fraud_Collier LLC'
#  'merchants__merchant_fraud_Connelly PLC'
#  'merchants__merchant_fraud_Connelly, Reichert and Fritsch'
#  'merchants__merchant_fraud_Connelly-Carter'
#  'merchants__merchant_fraud_Conroy Ltd'
#  'merchants__merchant_fraud_Conroy, Balistreri and Gorczany'
#  'merchants__merchant_fraud_Conroy-Cruickshank'
#  'merchants__merchant_fraud_Conroy-Emard'
#  'merchants__merchant_fraud_Cormier LLC'
#  'merchants__merchant_fraud_Cormier, Stracke and Thiel'
#  'merchants__merchant_fraud_Corwin-Collins'
#  'merchants__merchant_fraud_Corwin-Gorczany'
#  'merchants__merchant_fraud_Corwin-Romaguera'
#  'merchants__merchant_fraud_Cremin, Hamill and Reichel'
#  'merchants__merchant_fraud_Crist, Jakubowski and Littel'
#  'merchants__merchant_fraud_Crona and Sons'
#  'merchants__merchant_fraud_Cronin, Kshlerin and Weber'
#  'merchants__merchant_fraud_Crooks and Sons'
#  'merchants__merchant_fraud_Cruickshank-Mills'
#  'merchants__merchant_fraud_Cummerata-Hilpert'
#  'merchants__merchant_fraud_Cummerata-Jones'
#  'merchants__merchant_fraud_Cummings Group'
#  'merchants__merchant_fraud_Cummings LLC'
#  'merchants__merchant_fraud_Dach-Borer'
#  'merchants__merchant_fraud_Dach-Nader'
#  'merchants__merchant_fraud_Dare, Casper and Bartoletti'
#  'merchants__merchant_fraud_Dare, Fritsch and Zboncak'
#  'merchants__merchant_fraud_Dare-Gibson'
#  'merchants__merchant_fraud_Dare-Marvin'
#  'merchants__merchant_fraud_Daugherty LLC'
#  'merchants__merchant_fraud_Daugherty, Pouros and Beahan'
#  'merchants__merchant_fraud_Daugherty-Thompson'
#  'merchants__merchant_fraud_Deckow-Dare'
#  "merchants__merchant_fraud_Deckow-O'Conner"
#  'merchants__merchant_fraud_Denesik and Sons'
#  'merchants__merchant_fraud_Denesik, Powlowski and Pouros'
#  'merchants__merchant_fraud_Dibbert and Sons'
#  'merchants__merchant_fraud_Dibbert-Green'
#  'merchants__merchant_fraud_Dicki Ltd'
#  'merchants__merchant_fraud_Dickinson Ltd'
#  'merchants__merchant_fraud_Dickinson-Rempel'
#  'merchants__merchant_fraud_Dietrich-Fadel'
#  'merchants__merchant_fraud_Donnelly LLC'
#  'merchants__merchant_fraud_Donnelly PLC'
#  'merchants__merchant_fraud_Dooley Inc'
#  'merchants__merchant_fraud_Dooley-Thompson'
#  'merchants__merchant_fraud_Douglas, DuBuque and McKenzie'
#  'merchants__merchant_fraud_Douglas, Schneider and Turner'
#  'merchants__merchant_fraud_Douglas-White'
#  'merchants__merchant_fraud_Doyle Ltd'
#  'merchants__merchant_fraud_DuBuque LLC'
#  'merchants__merchant_fraud_Durgan, Gislason and Spencer'
#  'merchants__merchant_fraud_Durgan-Auer'
#  'merchants__merchant_fraud_Ebert-Daugherty'
#  'merchants__merchant_fraud_Effertz LLC'
#  'merchants__merchant_fraud_Effertz, Welch and Schowalter'
#  'merchants__merchant_fraud_Eichmann, Bogan and Rodriguez'
#  'merchants__merchant_fraud_Eichmann, Hayes and Treutel'
#  'merchants__merchant_fraud_Eichmann-Kilback'
#  'merchants__merchant_fraud_Eichmann-Russel'
#  'merchants__merchant_fraud_Emard Inc'
#  'merchants__merchant_fraud_Emmerich-Luettgen'
#  'merchants__merchant_fraud_Emmerich-Rau'
#  'merchants__merchant_fraud_Erdman-Durgan'
#  'merchants__merchant_fraud_Erdman-Ebert'
#  'merchants__merchant_fraud_Erdman-Kertzmann'
#  'merchants__merchant_fraud_Erdman-Schaden'
#  'merchants__merchant_fraud_Ernser-Feest'
#  'merchants__merchant_fraud_Ernser-Lynch'
#  'merchants__merchant_fraud_Fadel Inc'
#  'merchants__merchant_fraud_Fadel, Mertz and Rippin'
#  'merchants__merchant_fraud_Fadel-Hilpert'
#  'merchants__merchant_fraud_Fahey Inc'
#  'merchants__merchant_fraud_Feil, Hilpert and Koss'
#  'merchants__merchant_fraud_Feil-Morar'
#  'merchants__merchant_fraud_Ferry, Lynch and Kautzer'
#  'merchants__merchant_fraud_Ferry, Reichel and DuBuque'
#  'merchants__merchant_fraud_Fisher Inc'
#  'merchants__merchant_fraud_Fisher-Schowalter'
#  'merchants__merchant_fraud_Flatley Group'
#  'merchants__merchant_fraud_Flatley-Durgan'
#  'merchants__merchant_fraud_Frami Group'
#  'merchants__merchant_fraud_Friesen Inc'
#  'merchants__merchant_fraud_Friesen Ltd'
#  "merchants__merchant_fraud_Friesen-D'Amore"
#  'merchants__merchant_fraud_Friesen-Ortiz'
#  'merchants__merchant_fraud_Friesen-Stamm'
#  'merchants__merchant_fraud_Fritsch LLC'
#  'merchants__merchant_fraud_Fritsch and Sons'
#  'merchants__merchant_fraud_Funk Group'
#  'merchants__merchant_fraud_Gaylord-Powlowski'
#  'merchants__merchant_fraud_Gerhold LLC'
#  'merchants__merchant_fraud_Gerlach Inc'
#  'merchants__merchant_fraud_Gibson-Deckow'
#  'merchants__merchant_fraud_Gislason Group'
#  'merchants__merchant_fraud_Gleason and Sons'
#  'merchants__merchant_fraud_Gleason-Macejkovic'
#  'merchants__merchant_fraud_Goldner, Kovacek and Abbott'
#  'merchants__merchant_fraud_Goldner-Lemke'
#  'merchants__merchant_fraud_Goodwin-Nitzsche'
#  'merchants__merchant_fraud_Gottlieb Group'
#  'merchants__merchant_fraud_Gottlieb, Considine and Schultz'
#  'merchants__merchant_fraud_Gottlieb-Hansen'
#  'merchants__merchant_fraud_Goyette Inc'
#  'merchants__merchant_fraud_Goyette, Howell and Collier'
#  'merchants__merchant_fraud_Goyette-Gerhold'
#  'merchants__merchant_fraud_Goyette-Herzog'
#  'merchants__merchant_fraud_Graham and Sons'
#  'merchants__merchant_fraud_Graham, Hegmann and Hammes'
#  'merchants__merchant_fraud_Greenfelder, Bartoletti and Davis'
#  'merchants__merchant_fraud_Greenholt Ltd'
#  'merchants__merchant_fraud_Greenholt, Jacobi and Gleason'
#  "merchants__merchant_fraud_Greenholt, O'Hara and Balistreri"
#  'merchants__merchant_fraud_Grimes LLC'
#  'merchants__merchant_fraud_Gulgowski LLC'
#  'merchants__merchant_fraud_Gutmann Ltd'
#  'merchants__merchant_fraud_Gutmann, McLaughlin and Wiza'
#  'merchants__merchant_fraud_Gutmann-Upton'
#  'merchants__merchant_fraud_Haag-Blanda'
#  'merchants__merchant_fraud_Hackett Group'
#  'merchants__merchant_fraud_Hackett-Lueilwitz'
#  'merchants__merchant_fraud_Hagenes, Hermann and Stroman'
#  'merchants__merchant_fraud_Hagenes, Kohler and Hoppe'
#  'merchants__merchant_fraud_Hahn, Bahringer and McLaughlin'
#  'merchants__merchant_fraud_Hahn, Douglas and Schowalter'
#  'merchants__merchant_fraud_Haley Group'
#  'merchants__merchant_fraud_Haley, Batz and Auer'
#  'merchants__merchant_fraud_Haley, Jewess and Bechtelar'
#  'merchants__merchant_fraud_Halvorson Group'
#  "merchants__merchant_fraud_Hamill-D'Amore"
#  'merchants__merchant_fraud_Hamill-Daugherty'
#  'merchants__merchant_fraud_Hammes-Beatty'
#  'merchants__merchant_fraud_Harber Inc'
#  'merchants__merchant_fraud_Harris Group'
#  'merchants__merchant_fraud_Harris Inc'
#  'merchants__merchant_fraud_Harris, Gusikowski and Heaney'
#  'merchants__merchant_fraud_Hartmann, Rowe and Hermann'
#  'merchants__merchant_fraud_Hauck, Dietrich and Funk'
#  'merchants__merchant_fraud_Hayes, Marquardt and Dibbert'
#  'merchants__merchant_fraud_Heaney-Marquardt'
#  'merchants__merchant_fraud_Heathcote LLC'
#  'merchants__merchant_fraud_Heathcote, Yost and Kertzmann'
#  'merchants__merchant_fraud_Heidenreich PLC'
#  'merchants__merchant_fraud_Heller PLC'
#  'merchants__merchant_fraud_Heller, Gutmann and Zieme'
#  'merchants__merchant_fraud_Heller-Abshire'
#  'merchants__merchant_fraud_Heller-Langosh'
#  'merchants__merchant_fraud_Herman Inc'
#  'merchants__merchant_fraud_Herman, Treutel and Dickens'
#  'merchants__merchant_fraud_Hermann and Sons'
#  'merchants__merchant_fraud_Hermann-Gaylord'
#  'merchants__merchant_fraud_Hermiston, Pacocha and Smith'
#  'merchants__merchant_fraud_Hermiston, Russel and Price'
#  'merchants__merchant_fraud_Herzog Ltd'
#  'merchants__merchant_fraud_Hettinger, McCullough and Fay'
#  'merchants__merchant_fraud_Hickle Group'
#  'merchants__merchant_fraud_Hills, Hegmann and Schaefer'
#  'merchants__merchant_fraud_Hills-Boyer'
#  'merchants__merchant_fraud_Hills-Olson'
#  'merchants__merchant_fraud_Hills-Witting'
#  'merchants__merchant_fraud_Hilpert-Conroy'
#  'merchants__merchant_fraud_Hintz, Bauch and Smith'
#  'merchants__merchant_fraud_Hintz-Bruen'
#  'merchants__merchant_fraud_Hirthe-Beier'
#  'merchants__merchant_fraud_Hodkiewicz, Prohaska and Paucek'
#  'merchants__merchant_fraud_Homenick LLC'
#  'merchants__merchant_fraud_Hoppe, Harris and Bednar'
#  'merchants__merchant_fraud_Hoppe-Parisian'
#  'merchants__merchant_fraud_Howe Ltd' 'merchants__merchant_fraud_Howe PLC'
#  'merchants__merchant_fraud_Hudson-Grady'
#  'merchants__merchant_fraud_Hudson-Ratke'
#  'merchants__merchant_fraud_Huel Ltd'
#  'merchants__merchant_fraud_Huel, Hammes and Witting'
#  'merchants__merchant_fraud_Huel-Langworth'
#  'merchants__merchant_fraud_Huels-Hahn'
#  'merchants__merchant_fraud_Huels-Nolan'
#  'merchants__merchant_fraud_Hyatt, Russel and Gleichner'
#  'merchants__merchant_fraud_Hyatt-Blick'
#  'merchants__merchant_fraud_Jacobi Inc'
#  'merchants__merchant_fraud_Jacobi and Sons'
#  'merchants__merchant_fraud_Jakubowski Group'
#  'merchants__merchant_fraud_Jakubowski Inc'
#  'merchants__merchant_fraud_Jaskolski-Dibbert'
#  'merchants__merchant_fraud_Jaskolski-Vandervort'
#  'merchants__merchant_fraud_Jast Ltd'
#  'merchants__merchant_fraud_Jast and Sons'
#  'merchants__merchant_fraud_Jast-McDermott'
#  'merchants__merchant_fraud_Jenkins, Hauck and Friesen'
#  'merchants__merchant_fraud_Jerde-Hermann'
#  'merchants__merchant_fraud_Jewess LLC'
#  'merchants__merchant_fraud_Johns Inc'
#  'merchants__merchant_fraud_Johns-Hoeger'
#  'merchants__merchant_fraud_Johnson, Runolfsdottir and Mayer'
#  'merchants__merchant_fraud_Johnston, Nikolaus and Maggio'
#  'merchants__merchant_fraud_Johnston-Casper'
#  'merchants__merchant_fraud_Jones, Sawayn and Romaguera'
#  'merchants__merchant_fraud_Kassulke Inc'
#  'merchants__merchant_fraud_Kassulke PLC'
#  'merchants__merchant_fraud_Kautzer and Sons'
#  'merchants__merchant_fraud_Keeling-Crist'
#  'merchants__merchant_fraud_Kemmer-Buckridge'
#  'merchants__merchant_fraud_Kemmer-Reinger'
#  'merchants__merchant_fraud_Kerluke Inc'
#  'merchants__merchant_fraud_Kerluke PLC'
#  'merchants__merchant_fraud_Kerluke, Considine and Macejkovic'
#  'merchants__merchant_fraud_Kerluke, Kertzmann and Wiza'
#  'merchants__merchant_fraud_Kerluke-Abshire'
#  'merchants__merchant_fraud_Kertzmann LLC'
#  'merchants__merchant_fraud_Kessler Group'
#  'merchants__merchant_fraud_Kessler Inc'
#  'merchants__merchant_fraud_Kiehn Inc'
#  'merchants__merchant_fraud_Kiehn-Emmerich'
#  'merchants__merchant_fraud_Kihn Inc'
#  'merchants__merchant_fraud_Kihn, Abernathy and Douglas'
#  'merchants__merchant_fraud_Kihn, Brakus and Goyette'
#  'merchants__merchant_fraud_Kihn-Fritsch'
#  'merchants__merchant_fraud_Kihn-Schuster'
#  'merchants__merchant_fraud_Kilback Group'
#  'merchants__merchant_fraud_Kilback LLC'
#  'merchants__merchant_fraud_Kilback and Sons'
#  'merchants__merchant_fraud_Kilback, Nitzsche and Leffler'
#  'merchants__merchant_fraud_Kirlin and Sons'
#  'merchants__merchant_fraud_Klein Group'
#  'merchants__merchant_fraud_Kling Inc'
#  'merchants__merchant_fraud_Kling, Howe and Schneider'
#  'merchants__merchant_fraud_Kling-Ernser'
#  'merchants__merchant_fraud_Kling-Grant'
#  'merchants__merchant_fraud_Klocko LLC'
#  'merchants__merchant_fraud_Klocko, Runolfsdottir and Breitenberg'
#  'merchants__merchant_fraud_Koelpin and Sons'
#  'merchants__merchant_fraud_Koepp-Parker'
#  'merchants__merchant_fraud_Koepp-Witting'
#  'merchants__merchant_fraud_Kohler, Lindgren and Koelpin'
#  'merchants__merchant_fraud_Konopelski, Schneider and Hartmann'
#  'merchants__merchant_fraud_Koss and Sons'
#  'merchants__merchant_fraud_Koss, Hansen and Lueilwitz'
#  'merchants__merchant_fraud_Koss, McLaughlin and Mayer'
#  'merchants__merchant_fraud_Kovacek Ltd'
#  'merchants__merchant_fraud_Kovacek, Dibbert and Ondricka'
#  'merchants__merchant_fraud_Kozey-Boehm'
#  'merchants__merchant_fraud_Kozey-Kuhlman'
#  'merchants__merchant_fraud_Kozey-McDermott'
#  'merchants__merchant_fraud_Kris-Kertzmann'
#  'merchants__merchant_fraud_Kris-Padberg'
#  'merchants__merchant_fraud_Kris-Weimann'
#  'merchants__merchant_fraud_Kub PLC'
#  'merchants__merchant_fraud_Kub-Heaney'
#  'merchants__merchant_fraud_Kuhic Inc'
#  'merchants__merchant_fraud_Kuhic LLC'
#  'merchants__merchant_fraud_Kuhic, Bins and Pfeffer'
#  'merchants__merchant_fraud_Kuhn Group'
#  'merchants__merchant_fraud_Kuhn LLC'
#  'merchants__merchant_fraud_Kulas Group'
#  'merchants__merchant_fraud_Kunde-Sanford'
#  'merchants__merchant_fraud_Kunze Inc'
#  'merchants__merchant_fraud_Kunze, Larkin and Mayert'
#  'merchants__merchant_fraud_Kuphal-Bartoletti'
#  'merchants__merchant_fraud_Kuphal-Predovic'
#  'merchants__merchant_fraud_Kuphal-Toy'
#  'merchants__merchant_fraud_Kutch Group'
#  'merchants__merchant_fraud_Kutch LLC'
#  'merchants__merchant_fraud_Kutch and Sons'
#  'merchants__merchant_fraud_Kutch, Hermiston and Farrell'
#  'merchants__merchant_fraud_Kutch, Steuber and Gerhold'
#  'merchants__merchant_fraud_Kutch-Ferry'
#  'merchants__merchant_fraud_Kutch-Hegmann'
#  'merchants__merchant_fraud_Kutch-Wilderman'
#  'merchants__merchant_fraud_Kuvalis Ltd'
#  'merchants__merchant_fraud_Labadie LLC'
#  'merchants__merchant_fraud_Labadie, Treutel and Bode'
#  'merchants__merchant_fraud_Lakin, Ferry and Beatty'
#  'merchants__merchant_fraud_Lang, Towne and Schuppe'
#  'merchants__merchant_fraud_Langosh, Wintheiser and Hyatt'
#  'merchants__merchant_fraud_Langworth LLC'
#  'merchants__merchant_fraud_Langworth, Boehm and Gulgowski'
#  'merchants__merchant_fraud_Larkin Ltd'
#  'merchants__merchant_fraud_Larkin, Stracke and Greenfelder'
#  'merchants__merchant_fraud_Larson, Quitzon and Spencer'
#  'merchants__merchant_fraud_Larson-Moen'
#  'merchants__merchant_fraud_Leannon-Nikolaus'
#  'merchants__merchant_fraud_Leannon-Ward'
#  'merchants__merchant_fraud_Lebsack and Sons'
#  'merchants__merchant_fraud_Ledner, Hartmann and Feest'
#  'merchants__merchant_fraud_Ledner-Pfannerstill'
#  'merchants__merchant_fraud_Leffler-Goldner'
#  'merchants__merchant_fraud_Lehner, Mosciski and King'
#  'merchants__merchant_fraud_Lehner, Reichert and Mills'
#  'merchants__merchant_fraud_Lemke and Sons'
#  'merchants__merchant_fraud_Lemke-Gutmann'
#  'merchants__merchant_fraud_Lesch Ltd'
#  "merchants__merchant_fraud_Lesch, D'Amore and Brown"
#  'merchants__merchant_fraud_Lind, Huel and McClure'
#  'merchants__merchant_fraud_Lind-Buckridge'
#  'merchants__merchant_fraud_Little Ltd'
#  'merchants__merchant_fraud_Little, Gutmann and Lynch'
#  'merchants__merchant_fraud_Little-Gleichner'
#  'merchants__merchant_fraud_Lockman Ltd'
#  'merchants__merchant_fraud_Lockman, West and Runte'
#  'merchants__merchant_fraud_Lowe, Dietrich and Erdman'
#  'merchants__merchant_fraud_Lubowitz, Terry and Stracke'
#  'merchants__merchant_fraud_Lubowitz-Walter'
#  'merchants__merchant_fraud_Luettgen PLC'
#  'merchants__merchant_fraud_Lynch Ltd'
#  'merchants__merchant_fraud_Lynch-Mohr'
#  'merchants__merchant_fraud_Lynch-Wisozk'
#  'merchants__merchant_fraud_Macejkovic-Lesch'
#  'merchants__merchant_fraud_Maggio-Fahey'
#  'merchants__merchant_fraud_Mante Group'
#  'merchants__merchant_fraud_Mante, Luettgen and Hackett'
#  'merchants__merchant_fraud_Marks Inc'
#  'merchants__merchant_fraud_Marvin-Lind'
#  'merchants__merchant_fraud_Mayert Group'
#  'merchants__merchant_fraud_McCullough Group'
#  'merchants__merchant_fraud_McCullough LLC'
#  'merchants__merchant_fraud_McCullough, Hudson and Schuster'
#  'merchants__merchant_fraud_McDermott, Osinski and Morar'
#  'merchants__merchant_fraud_McDermott-Rice'
#  'merchants__merchant_fraud_McDermott-Weimann'
#  'merchants__merchant_fraud_McGlynn-Heathcote'
#  'merchants__merchant_fraud_McGlynn-Jaskolski'
#  'merchants__merchant_fraud_McKenzie-Huels'
#  'merchants__merchant_fraud_McLaughlin, Armstrong and Koepp'
#  'merchants__merchant_fraud_Medhurst Inc'
#  'merchants__merchant_fraud_Medhurst PLC'
#  'merchants__merchant_fraud_Medhurst, Cartwright and Ebert'
#  'merchants__merchant_fraud_Medhurst, Labadie and Gottlieb'
#  'merchants__merchant_fraud_Metz, Russel and Metz'
#  'merchants__merchant_fraud_Metz-Boehm'
#  'merchants__merchant_fraud_Miller-Harris'
#  'merchants__merchant_fraud_Miller-Hauck'
#  'merchants__merchant_fraud_Moen, Reinger and Murphy'
#  'merchants__merchant_fraud_Mohr Inc'
#  'merchants__merchant_fraud_Mohr-Bayer'
#  'merchants__merchant_fraud_Monahan, Bogisich and Ledner'
#  'merchants__merchant_fraud_Monahan, Hermann and Johns'
#  'merchants__merchant_fraud_Monahan-Morar'
#  'merchants__merchant_fraud_Moore, Dibbert and Koepp'
#  'merchants__merchant_fraud_Moore, Williamson and Emmerich'
#  'merchants__merchant_fraud_Morar Inc'
#  'merchants__merchant_fraud_Morissette LLC'
#  'merchants__merchant_fraud_Morissette PLC'
#  'merchants__merchant_fraud_Morissette, Weber and Wiegand'
#  'merchants__merchant_fraud_Morissette-Schaefer'
#  'merchants__merchant_fraud_Mosciski Group'
#  'merchants__merchant_fraud_Mosciski, Gislason and Mertz'
#  'merchants__merchant_fraud_Mosciski, Ziemann and Farrell'
#  'merchants__merchant_fraud_Mraz-Herzog'
#  'merchants__merchant_fraud_Mueller, Gerhold and Mueller'
#  'merchants__merchant_fraud_Murray Ltd'
#  'merchants__merchant_fraud_Murray-Smitham'
#  'merchants__merchant_fraud_Nader-Heller'
#  'merchants__merchant_fraud_Nader-Maggio'
#  'merchants__merchant_fraud_Nicolas, Hills and McGlynn'
#  'merchants__merchant_fraud_Nienow PLC'
#  'merchants__merchant_fraud_Nienow, Ankunding and Collier'
#  'merchants__merchant_fraud_Nienow, Barrows and Romaguera'
#  'merchants__merchant_fraud_Nitzsche, Kessler and Wolff'
#  'merchants__merchant_fraud_Nolan-Williamson'
#  "merchants__merchant_fraud_O'Connell, Botsford and Hand"
#  "merchants__merchant_fraud_O'Connell-Ullrich"
#  "merchants__merchant_fraud_O'Hara-Wilderman"
#  "merchants__merchant_fraud_O'Keefe-Hudson"
#  "merchants__merchant_fraud_O'Keefe-Wisoky"
#  "merchants__merchant_fraud_O'Reilly, Mohr and Purdy"
#  'merchants__merchant_fraud_Okuneva, Schneider and Rau'
#  'merchants__merchant_fraud_Olson, Becker and Koch'
#  'merchants__merchant_fraud_Ortiz Group'
#  'merchants__merchant_fraud_Osinski Inc'
#  'merchants__merchant_fraud_Osinski, Ledner and Leuschke'
#  'merchants__merchant_fraud_Pacocha-Bauch'
#  "merchants__merchant_fraud_Pacocha-O'Reilly"
#  'merchants__merchant_fraud_Pacocha-Weissnat'
#  'merchants__merchant_fraud_Padberg-Rogahn'
#  'merchants__merchant_fraud_Padberg-Sauer'
#  'merchants__merchant_fraud_Padberg-Welch'
#  'merchants__merchant_fraud_Pagac LLC'
#  'merchants__merchant_fraud_Parisian and Sons'
#  'merchants__merchant_fraud_Parisian, Schiller and Altenwerth'
#  'merchants__merchant_fraud_Parker, Nolan and Trantow'
#  'merchants__merchant_fraud_Parker-Kunde'
#  'merchants__merchant_fraud_Paucek-Wiza'
#  'merchants__merchant_fraud_Pfeffer LLC'
#  'merchants__merchant_fraud_Pfeffer and Sons'
#  'merchants__merchant_fraud_Pollich LLC'
#  'merchants__merchant_fraud_Pouros, Walker and Spencer'
#  'merchants__merchant_fraud_Pouros-Conroy'
#  'merchants__merchant_fraud_Pouros-Haag'
#  'merchants__merchant_fraud_Powlowski-Weimann'
#  'merchants__merchant_fraud_Predovic Inc'
#  'merchants__merchant_fraud_Price Inc'
#  'merchants__merchant_fraud_Prohaska-Murray'
#  'merchants__merchant_fraud_Prosacco LLC'
#  'merchants__merchant_fraud_Prosacco, Kreiger and Kovacek'
#  'merchants__merchant_fraud_Quitzon, Green and Bashirian'
#  'merchants__merchant_fraud_Quitzon-Goyette'
#  'merchants__merchant_fraud_Ratke and Sons'
#  'merchants__merchant_fraud_Rau and Sons'
#  'merchants__merchant_fraud_Rau-Grant'
#  'merchants__merchant_fraud_Rau-Robel'
#  'merchants__merchant_fraud_Raynor, Feest and Miller'
#  'merchants__merchant_fraud_Raynor, Reinger and Hagenes'
#  'merchants__merchant_fraud_Reichel Inc'
#  'merchants__merchant_fraud_Reichel LLC'
#  'merchants__merchant_fraud_Reichel, Bradtke and Blanda'
#  'merchants__merchant_fraud_Reichert, Huels and Hoppe'
#  'merchants__merchant_fraud_Reichert, Rowe and Mraz'
#  'merchants__merchant_fraud_Reichert, Shanahan and Hayes'
#  'merchants__merchant_fraud_Reichert-Weissnat'
#  'merchants__merchant_fraud_Reilly LLC'
#  'merchants__merchant_fraud_Reilly and Sons'
#  'merchants__merchant_fraud_Reilly, Heaney and Cole'
#  'merchants__merchant_fraud_Reinger, Weissnat and Strosin'
#  'merchants__merchant_fraud_Rempel Inc'
#  'merchants__merchant_fraud_Rempel PLC'
#  'merchants__merchant_fraud_Renner Ltd'
#  'merchants__merchant_fraud_Reynolds-Schinner'
#  'merchants__merchant_fraud_Rippin, Kub and Mann'
#  'merchants__merchant_fraud_Rippin-VonRueden'
#  'merchants__merchant_fraud_Ritchie, Bradtke and Stiedemann'
#  'merchants__merchant_fraud_Ritchie, Oberbrunner and Cremin'
#  'merchants__merchant_fraud_Robel, Cummerata and Prosacco'
#  'merchants__merchant_fraud_Roberts, Daniel and Macejkovic'
#  'merchants__merchant_fraud_Roberts, Ryan and Smith'
#  'merchants__merchant_fraud_Roberts-Beahan'
#  'merchants__merchant_fraud_Rodriguez Group'
#  'merchants__merchant_fraud_Rodriguez, Yost and Jenkins'
#  'merchants__merchant_fraud_Rohan, White and Aufderhar'
#  'merchants__merchant_fraud_Rolfson-Kunde'
#  'merchants__merchant_fraud_Romaguera Ltd'
#  'merchants__merchant_fraud_Romaguera and Sons'
#  'merchants__merchant_fraud_Romaguera, Cruickshank and Greenholt'
#  'merchants__merchant_fraud_Romaguera, Wehner and Tromp'
#  'merchants__merchant_fraud_Roob LLC'
#  'merchants__merchant_fraud_Roob, Conn and Tremblay'
#  'merchants__merchant_fraud_Roob-Okuneva'
#  'merchants__merchant_fraud_Rowe, Batz and Goodwin'
#  'merchants__merchant_fraud_Rowe-Vandervort'
#  'merchants__merchant_fraud_Ruecker Group'
#  'merchants__merchant_fraud_Ruecker, Beer and Collier'
#  'merchants__merchant_fraud_Ruecker-Mayert'
#  'merchants__merchant_fraud_Runolfsdottir, Mueller and Hand'
#  'merchants__merchant_fraud_Runolfsson and Sons'
#  'merchants__merchant_fraud_Runte, Green and Emard'
#  'merchants__merchant_fraud_Runte-Mohr'
#  'merchants__merchant_fraud_Rutherford, Homenick and Bergstrom'
#  'merchants__merchant_fraud_Rutherford-Mertz'
#  'merchants__merchant_fraud_Satterfield-Lowe'
#  'merchants__merchant_fraud_Sawayn PLC'
#  'merchants__merchant_fraud_Schaefer Ltd'
#  'merchants__merchant_fraud_Schaefer, Fay and Hilll'
#  'merchants__merchant_fraud_Schaefer, Maggio and Daugherty'
#  'merchants__merchant_fraud_Schaefer, McGlynn and Bosco'
#  "merchants__merchant_fraud_Schamberger-O'Keefe"
#  'merchants__merchant_fraud_Schiller Ltd'
#  'merchants__merchant_fraud_Schiller, Blanda and Johnson'
#  'merchants__merchant_fraud_Schimmel-Olson'
#  'merchants__merchant_fraud_Schmeler Inc'
#  'merchants__merchant_fraud_Schmeler, Bashirian and Price'
#  'merchants__merchant_fraud_Schmeler-Howe'
#  'merchants__merchant_fraud_Schmidt and Sons'
#  'merchants__merchant_fraud_Schmidt-Larkin'
#  'merchants__merchant_fraud_Schmitt Inc'
#  'merchants__merchant_fraud_Schmitt Ltd'
#  'merchants__merchant_fraud_Schneider, Hayes and Nikolaus'
#  'merchants__merchant_fraud_Schoen Ltd'
#  'merchants__merchant_fraud_Schoen, Kuphal and Nitzsche'
#  'merchants__merchant_fraud_Schoen, Nienow and Bauch'
#  'merchants__merchant_fraud_Schoen-Quigley'
#  'merchants__merchant_fraud_Schroeder Group'
#  'merchants__merchant_fraud_Schroeder, Hauck and Treutel'
#  'merchants__merchant_fraud_Schroeder, Wolff and Hermiston'
#  'merchants__merchant_fraud_Schulist Ltd'
#  'merchants__merchant_fraud_Schultz, Simonis and Little'
#  'merchants__merchant_fraud_Schumm PLC'
#  'merchants__merchant_fraud_Schumm, Bauch and Ondricka'
#  'merchants__merchant_fraud_Schumm, McLaughlin and Carter'
#  'merchants__merchant_fraud_Schuppe LLC'
#  'merchants__merchant_fraud_Schuppe, Nolan and Hoeger'
#  'merchants__merchant_fraud_Schuppe-Schuppe'
#  'merchants__merchant_fraud_Shanahan-Lehner'
#  'merchants__merchant_fraud_Shields Inc'
#  'merchants__merchant_fraud_Shields-Wunsch'
#  'merchants__merchant_fraud_Simonis-Prohaska'
#  'merchants__merchant_fraud_Skiles LLC'
#  'merchants__merchant_fraud_Skiles-Ankunding'
#  'merchants__merchant_fraud_Smith-Stokes'
#  'merchants__merchant_fraud_Smitham-Boehm'
#  'merchants__merchant_fraud_Smitham-Schiller'
#  'merchants__merchant_fraud_Spencer PLC'
#  'merchants__merchant_fraud_Spencer-Runolfsson'
#  'merchants__merchant_fraud_Spinka Inc'
#  'merchants__merchant_fraud_Spinka-Welch'
#  'merchants__merchant_fraud_Sporer Inc'
#  'merchants__merchant_fraud_Sporer-Keebler'
#  'merchants__merchant_fraud_Stamm-Rodriguez'
#  'merchants__merchant_fraud_Stamm-Witting'
#  'merchants__merchant_fraud_Stanton, Jakubowski and Baumbach'
#  'merchants__merchant_fraud_Stark-Batz'
#  'merchants__merchant_fraud_Stark-Koss'
#  'merchants__merchant_fraud_Stehr, Jewess and Schimmel'
#  'merchants__merchant_fraud_Stiedemann Inc'
#  'merchants__merchant_fraud_Stiedemann Ltd'
#  'merchants__merchant_fraud_Stokes, Christiansen and Sipes'
#  'merchants__merchant_fraud_Stoltenberg-Beatty'
#  'merchants__merchant_fraud_Stracke-Lemke'
#  'merchants__merchant_fraud_Streich Ltd'
#  'merchants__merchant_fraud_Streich, Dietrich and Barton'
#  'merchants__merchant_fraud_Streich, Hansen and Veum'
#  'merchants__merchant_fraud_Streich, Rolfson and Wilderman'
#  'merchants__merchant_fraud_Stroman, Hudson and Erdman'
#  'merchants__merchant_fraud_Strosin-Cruickshank'
#  'merchants__merchant_fraud_Swaniawski, Bahringer and Ledner'
#  'merchants__merchant_fraud_Swaniawski, Lowe and Robel'
#  'merchants__merchant_fraud_Swaniawski, Nitzsche and Welch'
#  'merchants__merchant_fraud_Swift PLC'
#  'merchants__merchant_fraud_Swift, Bradtke and Marquardt'
#  'merchants__merchant_fraud_Terry Ltd'
#  'merchants__merchant_fraud_Terry, Johns and Bins'
#  'merchants__merchant_fraud_Terry-Huel'
#  'merchants__merchant_fraud_Thiel Ltd'
#  'merchants__merchant_fraud_Thiel PLC'
#  'merchants__merchant_fraud_Thiel-Thiel'
#  'merchants__merchant_fraud_Thompson-Gleason'
#  'merchants__merchant_fraud_Tillman LLC'
#  'merchants__merchant_fraud_Tillman, Dickinson and Labadie'
#  'merchants__merchant_fraud_Tillman, Fritsch and Schmitt'
#  'merchants__merchant_fraud_Torp, Muller and Borer'
#  'merchants__merchant_fraud_Torp-Labadie'
#  'merchants__merchant_fraud_Torp-Lemke'
#  'merchants__merchant_fraud_Torphy-Goyette'
#  'merchants__merchant_fraud_Torphy-Kertzmann'
#  'merchants__merchant_fraud_Towne LLC'
#  'merchants__merchant_fraud_Towne, Greenholt and Koepp'
#  'merchants__merchant_fraud_Towne, Walker and Borer'
#  'merchants__merchant_fraud_Trantow PLC'
#  'merchants__merchant_fraud_Treutel-King'
#  'merchants__merchant_fraud_Tromp Group'
#  'merchants__merchant_fraud_Tromp, Kerluke and Glover'
#  'merchants__merchant_fraud_Turcotte, Batz and Buckridge'
#  'merchants__merchant_fraud_Turcotte, McKenzie and Koss'
#  'merchants__merchant_fraud_Turcotte-Halvorson'
#  'merchants__merchant_fraud_Turner LLC'
#  'merchants__merchant_fraud_Turner and Sons'
#  'merchants__merchant_fraud_Turner, Ruecker and Parisian'
#  'merchants__merchant_fraud_Turner, Ziemann and Lehner'
#  'merchants__merchant_fraud_Ullrich Ltd'
#  'merchants__merchant_fraud_Upton PLC'
#  'merchants__merchant_fraud_Vandervort-Funk'
#  'merchants__merchant_fraud_Veum-Koelpin'
#  'merchants__merchant_fraud_Volkman Ltd'
#  'merchants__merchant_fraud_Volkman PLC'
#  'merchants__merchant_fraud_Volkman-Predovic'
#  'merchants__merchant_fraud_VonRueden Group'
#  'merchants__merchant_fraud_Waelchi Inc'
#  'merchants__merchant_fraud_Waelchi-Wolf'
#  'merchants__merchant_fraud_Walter, Hettinger and Kessler'
#  'merchants__merchant_fraud_Waters-Cruickshank'
#  'merchants__merchant_fraud_Watsica LLC'
#  'merchants__merchant_fraud_Watsica, Haag and Considine'
#  'merchants__merchant_fraud_Weber and Sons'
#  'merchants__merchant_fraud_Weber, Thiel and Hammes'
#  'merchants__merchant_fraud_Weimann, Kuhic and Beahan'
#  'merchants__merchant_fraud_Weimann-Lockman'
#  'merchants__merchant_fraud_Welch Inc'
#  'merchants__merchant_fraud_Welch, Rath and Koepp'
#  'merchants__merchant_fraud_White and Sons'
#  'merchants__merchant_fraud_Wiegand-Lowe'
#  'merchants__merchant_fraud_Wilkinson LLC'
#  'merchants__merchant_fraud_Wilkinson Ltd'
#  'merchants__merchant_fraud_Wilkinson PLC'
#  'merchants__merchant_fraud_Will Ltd'
#  'merchants__merchant_fraud_Williamson LLC'
#  'merchants__merchant_fraud_Willms, Kris and Bergnaum'
#  'merchants__merchant_fraud_Windler LLC'
#  'merchants__merchant_fraud_Windler, Goodwin and Kovacek'
#  'merchants__merchant_fraud_Wintheiser, Dietrich and Schimmel'
#  'merchants__merchant_fraud_Wisozk and Sons'
#  'merchants__merchant_fraud_Witting, Beer and Ernser'
#  'merchants__merchant_fraud_Wiza LLC'
#  'merchants__merchant_fraud_Wiza, Schaden and Stark'
#  'merchants__merchant_fraud_Wolf Inc'
#  'merchants__merchant_fraud_Wuckert, Wintheiser and Friesen'
#  'merchants__merchant_fraud_Wuckert-Goldner'
#  'merchants__merchant_fraud_Wuckert-Walter'
#  'merchants__merchant_fraud_Yost, Block and Koepp'
#  'merchants__merchant_fraud_Yost, Schamberger and Windler'
#  'merchants__merchant_fraud_Yost-Rogahn'
#  'merchants__merchant_fraud_Zboncak LLC'
#  'merchants__merchant_fraud_Zboncak Ltd'
#  'merchants__merchant_fraud_Zboncak, Rowe and Murazik'
#  'merchants__merchant_fraud_Zemlak Group'
#  'merchants__merchant_fraud_Zemlak, Tillman and Cremin'
#  'merchants__merchant_fraud_Ziemann-Waters'
#  'merchants__merchant_fraud_Zieme, Bode and Dooley'
#  'merchants__merchant_fraud_Zulauf LLC' 'remainder__Unnamed: 0'
#  'remainder__amt' 'remainder__lat' 'remainder__long'
#  'remainder__merch_lat' 'remainder__merch_long']

# %%
# logistic regression model

from sklearn.metrics import classification_report, confusion_matrix, average_precision_score
from sklearn.linear_model import LogisticRegression


# use balanced to let the model increase weighting for fraud cases
logistic_regression = LogisticRegression(
    class_weight='balanced',
    max_iter=10000,
    random_state=0
)

logistic_regression.fit(X_training_ohe, y_training)
lr_pred = logistic_regression.predict(X_testing_ohe)

# manipulating the threshold (threshold here is set to get some amount in each category of confusion matrix)
lr_prob = logistic_regression.predict_proba(X_testing_ohe)[:, 1]
threshold = 0.4
lr_pred = (lr_prob >= threshold).astype(int)

# print results
target_names = ["legit", "fraud"]
print(classification_report(y_test, lr_pred, target_names=target_names, zero_division=0))
print("PRAUC: ", average_precision_score(y_test, lr_prob))

cm = confusion_matrix(y_test,lr_pred)
cm_df = pd.DataFrame(
    cm,
    index=["Actual Legit", "Actual Fraud"],
    columns=["Predicted Legit", "Predicted Fraud"]
)

print(cm_df)
# Out:
#               precision    recall  f1-score   support
#
#        legit       1.00      0.88      0.94    553574
#        fraud       0.02      0.76      0.05      2145
#
#     accuracy                           0.88    555719
#    macro avg       0.51      0.82      0.49    555719
# weighted avg       1.00      0.88      0.93    555719
#
# PRAUC:  0.13636489718082287
#               Predicted Legit  Predicted Fraud
# Actual Legit           489024            64550
# Actual Fraud              506             1639

# %%
# SVM model
# have to use linearSVM because SVM scales horribly with this dataset
from sklearn.svm import LinearSVC, SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler


svm = LinearSVC(
    class_weight="balanced",
    max_iter=10000,
    random_state=0
)

svm.fit(X_training_ohe, y_training)
svm_pred = svm.predict(X_testing_ohe)

# manipulating the threshold (threshold here is set to get some amount in each category of confusion matrix)
decision_scores = svm.decision_function(X_testing_ohe)
threshold = 0.2 
svm_pred = (decision_scores >= threshold).astype(int)

print(classification_report(y_test, svm_pred, target_names=target_names, zero_division=0))
print("PRAUC: ", average_precision_score(y_test, decision_scores))

cm_svm = confusion_matrix(y_test, svm_pred)
cm_svm_df = pd.DataFrame(
    cm_svm,
    index=["Actual Legit", "Actual Fraud"],
    columns=["Predicted Legit", "Predicted Fraud"]
)

print(cm_svm_df)
# Out:
#               precision    recall  f1-score   support
#
#        legit       1.00      0.94      0.97    553574
#        fraud       0.04      0.72      0.08      2145
#
#     accuracy                           0.94    555719
#    macro avg       0.52      0.83      0.52    555719
# weighted avg       1.00      0.94      0.96    555719
#
# PRAUC:  0.16810179212455229
#               Predicted Legit  Predicted Fraud
# Actual Legit           518268            35306
# Actual Fraud              609             1536

# %%
# neural network (multilayer perceptron) (~2 min to run)
from sklearn.neural_network import MLPClassifier
from sklearn.utils.class_weight import compute_sample_weight


# baseline hyperparameters,
mlp = make_pipeline(StandardScaler(with_mean=False), MLPClassifier(
    hidden_layer_sizes=(128, 64), # larger dataset requires more nodes in each layer
    activation='relu',            
    solver='adam',
    alpha = 0.001,               
    max_iter=500,        
    random_state=0,
))

mlp.fit(X_training_ohe, y_training)
mlp_pred = mlp.predict(X_testing_ohe)

mlp_prob = mlp.predict_proba(X_testing_ohe)[:, 1]

# manipulating the threshold (threshold here is set to get some amount in each category of confusion matrix)
# 0.05 and above results in model not finding anything
threshold = 0.01
mlp_pred = (mlp_prob >= threshold).astype(int)

print(classification_report(y_test, mlp_pred, target_names=target_names, zero_division=0))
print("PRAUC: ", average_precision_score(y_test, mlp_prob))

cm_mlp = confusion_matrix(y_test, mlp_pred)
cm_mlp_df = pd.DataFrame(
    cm_mlp,
    index=["Actual Legit", "Actual Fraud"],
    columns=["Predicted Legit", "Predicted Fraud"]
)

print(cm_mlp_df)
# Out:
#               precision    recall  f1-score   support
#
#        legit       1.00      0.99      0.99    553574
#        fraud       0.21      0.83      0.33      2145
#
#     accuracy                           0.99    555719
#    macro avg       0.60      0.91      0.66    555719
# weighted avg       1.00      0.99      0.99    555719
#
# PRAUC:  0.6665958545528449
#               Predicted Legit  Predicted Fraud
# Actual Legit           546810             6764
# Actual Fraud              374             1771

# %%
# XGBoost
from xgboost import XGBClassifier


num_pos = y_training.sum()
num_neg = len(y_training) - num_pos
xgb = XGBClassifier(
    objective='binary:logistic',
    n_estimators=500,  
    max_depth=5,        
    learning_rate=0.05, 
    subsample=0.8,      
    colsample_bytree=0.8, 
    random_state=0,
    tree_method='hist', 
    scale_pos_weight=num_neg /num_pos, # balance the classes to have more weight on fraud cases
)

xgb.fit(X_training_ohe, y_training)
xgb_pred = xgb.predict(X_testing_ohe)

xgb_prob = xgb.predict_proba(X_testing_ohe)[:, 1]

# manipulating the threshold (threshold here is set to get some amount in each category of confusion matrix)
threshold = 0.4
xgb_pred = (xgb_prob >= threshold).astype(int)

print(classification_report(y_test, xgb_pred, target_names=target_names, zero_division=0))
print("PRAUC: ", average_precision_score(y_test, xgb_prob))

cm_xgb = confusion_matrix(y_test, xgb_pred)
cm_xgb_df = pd.DataFrame(
    cm_xgb,
    index=["Actual Legit", "Actual Fraud"],
    columns=["Predicted Legit", "Predicted Fraud"]
)

print(cm_xgb_df)
# Out:
#               precision    recall  f1-score   support
#
#        legit       1.00      0.90      0.95    553574
#        fraud       0.03      0.91      0.07      2145
#
#     accuracy                           0.90    555719
#    macro avg       0.52      0.90      0.51    555719
# weighted avg       1.00      0.90      0.95    555719
#
# PRAUC:  0.22927798211939696
#               Predicted Legit  Predicted Fraud
# Actual Legit           499762            53812
# Actual Fraud              200             1945

# %%
# Random Forest (~1-2 min)
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=500, 
    min_samples_split=2,
    random_state=42,
    class_weight='balanced',
    max_depth=15
)

# baseline test
rf.fit(X_training_ohe, y_training)
rf_pred = rf.predict(X_testing_ohe)

# manipulating the threshold (threshold here is set to get some amount in each category of confusion matrix)
rf_prob = rf.predict_proba(X_testing_ohe)[:, 1]
threshold = 0.45
rf_pred = (rf_prob >= threshold).astype(int)

print(classification_report(y_test, rf_pred, target_names=target_names, zero_division=0))
print("PRAUC: ", average_precision_score(y_test, rf_prob))

cm_rf = confusion_matrix(y_test, rf_pred)
cm_rf_df = pd.DataFrame(
    cm_rf,
    index=["Actual Legit", "Actual Fraud"],
    columns=["Predicted Legit", "Predicted Fraud"]
)

print(cm_rf_df)
# Out:
#               precision    recall  f1-score   support
#
#        legit       1.00      0.97      0.99    553574
#        fraud       0.09      0.74      0.16      2145
#
#     accuracy                           0.97    555719
#    macro avg       0.55      0.86      0.57    555719
# weighted avg       1.00      0.97      0.98    555719
#
# PRAUC:  0.1499692341120678
#               Predicted Legit  Predicted Fraud
# Actual Legit           537994            15580
# Actual Fraud              554             1591

# %%
# make the fraud test data for a model (20% of all false negatives)
def get_FN(pred):
    all_fn_indices = np.where((pred == 0) & (y_test.to_numpy() == 1))[0]

    picked_indices = np.random.choice(all_fn_indices, size=int(0.2 * len(all_fn_indices)), replace=False)
    return X_testing_ohe[picked_indices, :]

# functions for predicting with a threshold
def predict_with_threshold(model, threshold, data):
    prob = model.predict_proba(data)[:, 1]
    pred = (prob >= threshold).astype(int)

    return pred

def predict_with_threshold_svm(model, threshold, data):
    decision_scores = model.decision_function(data) 
    pred = (decision_scores >= threshold).astype(int)

    return pred

# get prediction based on specific model and data
def get_pred(index, data):
    if index == 0:
        return predict_with_threshold(logistic_regression, 0.4, data)
    elif index == 1:
        return predict_with_threshold_svm(svm, 0.2, data)
    elif index == 2:
        return predict_with_threshold(mlp, 0.01, data)
    elif index == 3:
        return predict_with_threshold(xgb, 0.4, data)
    else:
        return predict_with_threshold(rf, 0.45, data)
    
print(type(X_testing_ohe))
print(X_testing_ohe.shape)
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>
# (555719, 699)

# %%
# experiment
from numpy import random

models = [logistic_regression, svm, mlp, xgb, rf]
fraud_sets = [get_FN(lr_pred), get_FN(svm_pred), get_FN(mlp_pred), get_FN(xgb_pred), get_FN(rf_pred)]
model_losses = [0,0,0,0,0]

# probability of committing fraud (fraud procedure for now)
# can manipulate
fraud_prob = 0.1

# threshold to switch to another model if this monetary value is not reached 
# can manipulate
threshold = 100000

# amount of txns to pass before potentially switching
# can manipulate
window = 100000

# extract the amount column
feature_names = ct.get_feature_names_out()
amt_idx = list(feature_names).index("remainder__amt")

# total amount of money lost by all models
total_loss = 0
# total amount of money lost in a window
loss_at_model = 0

# counter for window
count = 0

# picks an index for a model
m = random.randint(0,4)

# fraud txn counter
fraud_count = 0
window_count = 0

loss_at_window = 0
loss_at_model = 0

for i in X_testing_ohe:
    # generate a float to decide whether or not to do fraud
    do_fraud = random.random()
    if do_fraud <= fraud_prob:
        # sample one txn uniformally
        rows = fraud_sets[m].shape[0]
        rand_idx = random.randint(0, rows - 1)
        fraud_txn = fraud_sets[m][rand_idx]

        fraud_count += 1
        # get the prediction for the transaction
        model_pred = get_pred(m, fraud_txn)
        if model_pred == 0: # money lost if model labels incorrectly
            loss_at_model += i[0, amt_idx]
            loss_at_window += i[0, amt_idx]

    if count == window: # end of window
        model_losses[m] += loss_at_model
        if loss_at_model <= threshold: # check threshold; switch to another model if threshold is not met
            m_prev = m
            while m_prev == m:
                m = random.randint(0,4)
            print("switch\n") # model switch indicated
            print("loss_at_model: ", loss_at_model)
            loss_at_model = 0

        total_loss += loss_at_window # add loss at window to total loss
        count = -1 # reset count

        window_count += 1
        print("loss_at_window: ", loss_at_window)
        loss_at_window = 0
    count += 1

print("Total loss: ",total_loss)
print("Ave. number of fraud_txns per window: ",(fraud_count / window_count))
print("Ave. loss per window: ",(total_loss / window_count))
print("Loss per model: ", model_losses)
# Out:
# loss_at_window:  699367.4299999982
# loss_at_window:  671011.6599999975
# loss_at_window:  665396.4099999999
# loss_at_window:  710402.2499999997
# loss_at_window:  701928.6299999987
# Total loss:  3448106.3799999943
# Ave. number of fraud_txns per window:  11059.0
# Ave. loss per window:  689621.2759999989
# Loss per model:  [np.float64(10299806.149999946), 0, 0, 0, 0]
